# %%
# !git clone https://github.com/jjeong3150/AIFFEL_final_pjt_book-recommendation-agent
# Out:
# Cloning into 'AIFFEL_final_pjt_book-recommendation-agent'...
# remote: Enumerating objects: 382, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 382 (delta 68), reused 0 (delta 0), pack-reused 270 (from 1)
# Receiving objects: 100% (382/382), 25.97 MiB | 10.88 MiB/s, done.
# Resolving deltas: 100% (194/194), done.
# Updating files: 100% (46/46), done.

# %% [markdown]
# # Main — CRS × User Simulation 오케스트레이션
#
# ```
# build_graph.ipynb  →  app, initial_state, config 제공 (while 루프 셀 제거 필요)
# user_sim.ipynb     →  UserSimAgent, PERSONA_TEMPLATES
# main.ipynb         →  Queue 기반으로 두 시스템 연결
# ```
#
# **주의**: `build_graph.ipynb`의 마지막 셀 (while 루프)은 주석 처리하거나 삭제하세요.
# 루프 로직은 이 노트북이 담당합니다.

# %% [markdown]
# ## 1. 노트북 로드

# %%
# CRS 시스템 로드 (app, initial_state, config 가 네임스페이스로 올라옴)
# %run /content/AIFFEL_final_project_peekabook/research/src/pipeline/build_graph.ipynb
# Out:
# fatal: destination path 'AIFFEL_final_pjt_book-recommendation-agent' already exists and is not an empty directory.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 51.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.6/99.6 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 63.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 22.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 83.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 59.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 92.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 6.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.42.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-exporter-otlp-proto-common==1.38.0, but you have opentelemetry-exporter-otlp-proto-common 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-proto==1.38.0, but you have opentelemetry-proto 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-sdk~=1.38.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# fatal: destination path 'AIFFEL_final_pjt_book-recommendation-agent' already exists and is not an empty directory.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.1/398.1 kB 7.8 MB/s eta 0:00:00
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# HTTP Error 503 thrown while requesting HEAD https://huggingface.co/BAAI/bge-m3/resolve/main/./modules.json
# WARNING:huggingface_hub.utils._http:HTTP Error 503 thrown while requesting HEAD https://huggingface.co/BAAI/bge-m3/resolve/main/./modules.json
# Retrying in 1s [Retry 1/5].
# WARNING:huggingface_hub.utils._http:Retrying in 1s [Retry 1/5].
# HTTP Error 503 thrown while requesting HEAD https://huggingface.co/BAAI/bge-m3/resolve/main/./modules.json
# WARNING:huggingface_hub.utils._http:HTTP Error 503 thrown while requesting HEAD https://huggingface.co/BAAI/bge-m3/resolve/main/./modules.json
# Retrying in 2s [Retry 2/5].
# WARNING:huggingface_hub.utils._http:Retrying in 2s [Retry 2/5].
# HTTP Error 503 thrown while requesting HEAD https://huggingface.co/BAAI/bge-m3/resolve/main/./modules.json
# WARNING:huggingface_hub.utils._http:HTTP Error 503 thrown while requesting HEAD https://huggingface.co/BAAI/bge-m3/resolve/main/./modules.json
# Retrying in 4s [Retry 3/5].
# WARNING:huggingface_hub.utils._http:Retrying in 4s [Retry 3/5].
# HTTP Error 503 thrown while requesting HEAD https://huggingface.co/BAAI/bge-m3/resolve/main/./modules.json
# WARNING:huggingface_hub.utils._http:HTTP Error 503 thrown while requesting HEAD https://huggingface.co/BAAI/bge-m3/resolve/main/./modules.json
# Retrying in 8s [Retry 4/5].
# WARNING:huggingface_hub.utils._http:Retrying in 8s [Retry 4/5].
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/15.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/444 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# [LocalReranker] 캐시 로드 실패 (Repo id must be in the form 'repo_name' or 'namespace/repo_name': '/content/drive/MyDrive/aiffel_final_pjt/models/BAAI_bge-reranker-v2-m3'. Use `repo_type` argument if needed.), HuggingFace에서 다운로드
# config.json:   0%|          | 0.00/795 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/393 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# [LocalReranker] 캐시 저장 완료: /content/drive/MyDrive/aiffel_final_pjt/models/BAAI_bge-reranker-v2-m3
# /tmp/ipykernel_2928/896750007.py:41: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent_executor = create_react_agent(

# %%
# User Sim 로드 (UserSimAgent, PERSONA_TEMPLATES 가 네임스페이스로 올라옴)
# %run /content/AIFFEL_final_project_peekabook/research/src/simulation/user_sim_test.ipynb
# Out:
# 사용 가능한 페르소나: ['직장인_SF팬', '대학생_문학팬', '중년_역사_비문학']
# UserSimAgent 정의 완료

# %% [markdown]
# ## 2. 오케스트레이션 설정

# %%
import queue
import threading
import json
import copy
from langchain_core.messages import HumanMessage

# 통신 큐
user_to_crs = queue.Queue()   # UserSim → CRS (사용자 응답)
crs_to_user = queue.Queue()   # CRS → UserSim (질문 or 완료 신호)

# 결과 수집
eval_results = []

print("큐 초기화 완료")
# Out:
# 큐 초기화 완료

# %% [markdown]
# ## 3. CRS 실행 함수
#
# `input()` 대신 `user_to_crs` 큐에서 읽어옵니다.

# %%
def _extract_ai_responses(state: dict[str, Any]) -> list[str]:
    """상태의 messages에서 마지막 사용자 메시지 이후의 AI 메시지들을 추출."""
    messages = state.get("messages", [])
    responses = []
    # 역순으로 순회하며 마지막 HumanMessage 이전의 AI 메시지들 수집
    for msg in reversed(messages):
        if isinstance(msg, HumanMessage) or getattr(msg, "type", None) == "human":
            break
        if isinstance(msg, AIMessage) or getattr(msg, "type", None) == "ai":
            responses.append(msg.content)
    responses.reverse()
    return responses

# %%
async def run_crs(thread_id: str):
    session_config = {"configurable": {"thread_id": thread_id}}
    state = copy.deepcopy(initial_state)
    result = await app.ainvoke(state, config=session_config)

    while True:
        snapshot = app.get_state(session_config)

        if snapshot.next == ():  # 그래프 완료
            crs_to_user.put({"__done__": True, "result": result})
            break

        # AI 질문 추출 후 UserSim에 전달
        ai_responses = _extract_ai_responses(result)
        if ai_responses:
            crs_to_user.put(ai_responses[-1])

        # UserSim 응답 대기
        user_input = user_to_crs.get()

        # 사용자 입력 주입 후 resume
        app.update_state(session_config, {"messages": [HumanMessage(content=user_input)]})
        result = await app.ainvoke(None, config=session_config)

print("run_crs 정의 완료")
# Out:
# run_crs 정의 완료

# %% [markdown]
# ## 4. UserSim 실행 함수

# %%
def run_user_sim(persona: dict, result_collector: list):
    """
    UserSimAgent를 실행하며 CRS 질문에 자동 응답합니다.
    세션이 끝나면 결과를 result_collector에 추가합니다.
    """
    agent = UserSimAgent(persona=persona, verbose=True)

    while True:
        message = crs_to_user.get()  # CRS 메시지 대기 (블로킹)

        if isinstance(message, dict) and message.get("__done__"):
            crs_result = message["result"]
            result_collector.append({
                "persona":         persona,
                "user_profile":    crs_result.get("user_profile", {}),
                "summary":         crs_result.get("summary", ""),
                "reflection":      crs_result.get("reflection", ""),
                "recommendations": crs_result.get("recommendations", []),
                "final_message": (
                    crs_result["messages"][-1].content
                    if crs_result.get("messages") else ""
                ),
                "conversation": agent.get_history()
            })
            break

        response = agent.answer(message)
        user_to_crs.put(response)

print("run_user_sim 정의 완료")
# Out:
# run_user_sim 정의 완료

# %% [markdown]
# ## 5. 단일 세션 실행

# %%
async def run_session(persona, eval_results, thread_id):
    t_user = threading.Thread(target=run_user_sim, args=(persona, eval_results))
    t_user.start()
    await run_crs(thread_id)
    t_user.join()

# 페르소나 선택
persona   = PERSONA_TEMPLATES["중년_역사_비문학"]
thread_id = "eval_session_001"

await run_session(persona, eval_results, thread_id)

print("\n" + "="*50)
print("세션 종료")
print("="*50)
# Out:
# [Turn 1]
#   CSR  : "사피엔스"를 통해 역사적 사건과 인물에 대한 깊이 있는 이해를 얻으셨다고 하셨는데요, 혹시 특정한 역사적 주제나 사건에 대해 더 알고 싶으신 것이 있으신가요? 이를 통해 여러분의 수업에 어떤 내용을 더하고 싶으신지 궁금합니다!
#   USER : 사피엔스를 읽고 인류의 진화와 사회 구조에 대한 시각이 많이 넓어졌어요. 특히 산업 혁명이나 제2차 세계대전 같은 큰 사건들이 개인과 사회에 미친 영향에 대해 더 깊이 알아보고 싶습니다. 이런 내용을 통해 학생들에게 역사적 사건의 맥락을 잘 설명해줄 수 있을 것 같아요.
#
# [Turn 2]
#   CSR  : 안녕하세요! 현재 학생들에게 역사적 사건을 설명하기 위해 깊이 있는 이해를 원하신다고 하셨는데, 이전에 읽었던 역사 관련 책이 있으신가요? 어떤 책이었고, 그 책을 통해 어떤 인사이트를 얻으셨는지 궁금합니다.
#   USER : 안녕하세요! 유발 하라리의 "사피엔스" 외에도 "총, 균, 쇠"를 읽어봤어요. 이 책을 통해 인류 문명의 발전이 어떻게 환경과 지리적 요인에 영향을 받았는지를 이해하게 되었고, 이것이 역사적 사건을 설명하는 데 큰 도움이 되고 있습니다. 학생들에게도 이런 관점을 통해 사건을 다각도로 분석할 수 있도록 하고 싶어요.
# 추출된 장르: []
#
# [Query Transformations]
#   [Step-back]  : 역사적 사건의 사회적 맥락과 개인의 경험을 심도 있게 탐구할 수 있는 도서를 추천해 주세요. 학생들과의 논의에서 풍부한 내용을 제공할 수 있도록 역사적 분석과 교육적 활용 가능성을 고려한 작품을 원합니다.
#   [Rewritten]  : "산업 혁명과 제2차 세계대전의 사회적 영향에 대한 심도 있는 역사적 분석을 제공하는 학술 서적. 인류의 진화와 사회 구조를 탐구하며 교육적 활용이 가능한 도서 추천."
#   [Sub-queries]: ['산업 혁명과 제2차 세계대전의 사회적 영향을 심도 있게 다룬 학술 서적을 찾고 있다.', '인류의 진화와 사회 구조에 대한 통찰을 제공하는 도서를 고려하고 싶다.', '교육적 활용을 염두에 두고, 역사적 사건이 현대 사회에 미친 영향을 분석한 책도 탐색하고 싶다.']
#
# [Reranking 결과]
#   score: 0.1198 | 꼬물꼬물 거꾸로 역사수업
#   score: 0.1196 | 아이는 성공하기 위해 태어난다
#   score: 0.0368 | 아담과 이브 그후 - 진화로 본 휴먼 섹슈얼리티
#   score: 0.0221 | 한국사회복지정책론
#   score: 0.0156 | 현대사회의 구조와 변동 - 신서 897
#   score: 0.0134 | 가장 쉬운 역사 첫걸음
#   score: 0.0099 | 미래사회와 인간관계
#   score: 0.0068 | 맞수로 읽는 우리 역사 - 생각하며 역사 읽기-삼국, 고려시대
#   score: 0.0058 | 미국의사회와문화
#   score: 0.0046 | 세계 영화사
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [도서관 목록 조회 API 통신 로그]
# 👉 실제 호출된 URL: http://data4library.kr/api/libSrch?authKey=%0916424b20e4393e27541144ae9873e2dd63a08d7a4eb6b73942c93b4d54f4241f&region=11&dtl_region=11230&pageSize=3&format=json
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
#
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [ISBN + 표지 URL 검색	API 통신 로그]
# 👉 실제 호출된 URL: https://openapi.naver.com/v1/search/book.json?query=%EA%BC%AC%EB%AC%BC%EA%BC%AC%EB%AC%BC+%EA%B1%B0%EA%BE%B8%EB%A1%9C+%EC%97%AD%EC%82%AC%EC%88%98%EC%97%85&display=1
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
#
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [ISBN + 표지 URL 검색	API 통신 로그]
# 👉 실제 호출된 URL: https://openapi.naver.com/v1/search/book.json?query=%ED%95%9C%EA%B5%AD%EC%82%AC%ED%9A%8C%EB%B3%B5%EC%A7%80%EC%A0%95%EC%B1%85%EB%A1%A0&display=1
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
#
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [ISBN + 표지 URL 검색	API 통신 로그]
# 👉 실제 호출된 URL: https://openapi.naver.com/v1/search/book.json?query=%ED%98%84%EB%8C%80%EC%82%AC%ED%9A%8C%EC%9D%98+%EA%B5%AC%EC%A1%B0%EC%99%80+%EB%B3%80%EB%8F%99+-+%EC%8B%A0%EC%84%9C+897&display=1
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
#
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [대출 가능 여부 조회 API 통신 로그]
# 👉 실제 호출된 URL: http://data4library.kr/api/bookExist?authKey=%0916424b20e4393e27541144ae9873e2dd63a08d7a4eb6b73942c93b4d54f4241f&libCode=111070&isbn13=9791159301056&format=json
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
#
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [대출 가능 여부 조회 API 통신 로그]
# 👉 실제 호출된 URL: http://data4library.kr/api/bookExist?authKey=%0916424b20e4393e27541144ae9873e2dd63a08d7a4eb6b73942c93b4d54f4241f&libCode=111526&isbn13=9791159301056&format=json
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
#
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [대출 가능 여부 조회 API 통신 로그]
# 👉 실제 호출된 URL: http://data4library.kr/api/bookExist?authKey=%0916424b20e4393e27541144ae9873e2dd63a08d7a4eb6b73942c93b4d54f4241f&libCode=111533&isbn13=9791155503232&format=json
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
#
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [대출 가능 여부 조회 API 통신 로그]
# 👉 실제 호출된 URL: http://data4library.kr/api/bookExist?authKey=%0916424b20e4393e27541144ae9873e2dd63a08d7a4eb6b73942c93b4d54f4241f&libCode=111533&isbn13=9791159301056&format=json
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
#
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [대출 가능 여부 조회 API 통신 로그]
# 👉 실제 호출된 URL: http://data4library.kr/api/bookExist?authKey=%0916424b20e4393e27541144ae9873e2dd63a08d7a4eb6b73942c93b4d54f4241f&libCode=111070&isbn13=9791155503232&format=json
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
#
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📡 [대출 가능 여부 조회 API 통신 로그]
# 👉 실제 호출된 URL: http://data4library.kr/api/bookExist?authKey=%0916424b20e4393e27541144ae9873e2dd63a08d7a4eb6b73942c93b4d54f4241f&libCode=111526&isbn13=9791155503232&format=json
# ▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲▲
#
#
# ==================================================
# 세션 종료
# ==================================================

# %% [markdown]
# ## 6. 결과 확인

# %%
if eval_results:
    r = eval_results[-1]

    print("[페르소나]")
    print(json.dumps(r["persona"], ensure_ascii=False, indent=2))

    print("\n[추출된 프로필]")
    print(r["user_profile"])

    print("\n[요약]")
    print("summary :", r["summary"])
    print("reflection :", r["reflection"])

    print("\n[책 리스트]")
    print(r["recommendations"])

    print("\n[추천 결과]")
    print(r["final_message"])
else:
    print("결과 없음")
# Out:
# [페르소나]
# {
#   "age_group": "40대 중반",
#   "job": "중학교 역사 교사",
#   "favorite_genre": "역사, 교양 비문학",
#   "reading_frequency": "한 달에 3~4권",
#   "mood": "수업에 활용할 수 있는 흥미로운 역사 이야기",
#   "disliked_genre": "공포, 오컬트",
#   "reading_experience": "유발 하라리의 사피엔스를 인상 깊게 읽음"
# }
#
# [추출된 프로필]
# reading_goal=ProfileSlot(value='학생들에게 역사적 사건의 맥락을 잘 설명해주기 위해 인류의 진화와 사회 구조에 대한 이해를 깊이 하고 싶음', status=<SlotStatus.FILLED: 'filled'>, retry_count=0, MAX_RETRIES=3) preferred_genre=ProfileSlot(value='역사', status=<SlotStatus.FILLED: 'filled'>, retry_count=0, MAX_RETRIES=3) reading_style=ProfileSlot(value='깊이 있는 내용 선호', status=<SlotStatus.FILLED: 'filled'>, retry_count=0, MAX_RETRIES=3) difficulty_level=ProfileSlot(value='학술적인 내용이 포함된 책 선호', status=<SlotStatus.FILLED: 'filled'>, retry_count=0, MAX_RETRIES=3) current_context=ProfileSlot(value='사피엔스를 통해 역사적 사건과 인물에 대한 시각이 넓어졌고, 더 깊이 있는 이해를 원함', status=<SlotStatus.FILLED: 'filled'>, retry_count=0, MAX_RETRIES=3)
#
# [요약]
# summary : 사용자는 학생들에게 역사적 사건의 맥락을 효과적으로 설명하기 위해 인류의 진화와 사회 구조에 대한 깊이 있는 이해를 원하고 있습니다. 역사 분야의 학술적인 내용을 선호하며, 특히 산업 혁명이나 제2차 세계대전과 같은 큰 사건들이 개인과 사회에 미친 영향을 탐구하고자 합니다. 이를 통해 학생들과의 논의에서 풍부한 내용을 제공할 수 있는 자료를 찾고 있습니다. 최근 읽은 "사피엔스"와 "총, 균, 쇠"에서 얻은 통찰력을 바탕으로, 심도 있는 역사적 분석을 담고 있는 책을 원하고 있습니다.
# reflection : 사용자는 역사적 사건을 심도 있게 이해하고 이를 교육적인 맥락에서 효과적으로 전달하고자 하는 강한 욕구를 가지고 있습니다. 이전에 읽은 책들이 지금의 인사이트와 요구를 형성하는 데 중요한 역할을 했으며, 이를 통해 학생들과의 논의에서 풍부한 내용을 제공하고자 합니다. 향후 독서 선택에서도 이러한 깊이 있는 분석과 교육적 활용 가능성을 고려할 것으로 보입니다.
#
# [책 리스트]
# [{'title': '꼬물꼬물 거꾸로 역사수업', 'author': '역모자들', 'isbn': '9791159301056', 'book_intro': '교사가 직접 역사수업 자료를 만들고, 학생들이 자료 조사를 하고 이를 기초로 현장 탐방과 토론을 하며 현재의 우리 사회를 돌아볼 수 있는 다양한 프로그램을 진행했다. 지난 일을 배...', 'cate_depth1': '사회/정치', 'reason': '이 책은 역사 교육을 위한 구체적인 방법론을 제시하여, 학생들에게 역사적 사건을 더 잘 이해시키고 토론할 수 있는 기회를 제공합니다. 사용자가 원하는 깊이 있는 역사적 분석을 교육적 맥락에서 효과적으로 활용할 수 있는 자료입니다.'}, {'title': '현대사회의 구조와 변동 - 신서 897', 'author': '박길성', 'isbn': '9788930070669', 'book_intro': '이 책은 현대사회의 구조와 변동에 관해 지적 관심을 가지고 있는 연구자들을 위해 만들었다. 즉, 현대사회의 흐름을 몇 가지의 담론으로 정리하고, 현대사회의 이슈를 천착하면서, 이 ...', 'cate_depth1': '사회/정치', 'reason': '역사적 사건들이 현대 사회에 미친 영향을 분석하는 데 있어 중요한 통찰을 제공합니다. 이는 사용자가 제2차 세계대전과 같은 큰 사건을 학생들에게 설명할 때 유용한 배경 지식을 제공할 것입니다.'}, {'title': '한국사회복지정책론', 'author': '신섭중', 'isbn': '9788971190739', 'book_intro': '크게 사회복지정책의 이론과 현대 한국 산업사회의 사회문제, 사회복지정책으로 구분하여 오늘날 우리나라가 직면하고 있는 생활상의 제반 사회문제를 폭넓게 고찰한 사회학 교수의 연구논저....', 'cate_depth1': '대학교재/전문서적', 'reason': '한국 사회의 역사적 맥락과 사회적 이슈를 이해하는 데 도움을 줄 수 있는 자료로, 사용자가 학생들과 논의할 때 풍부한 내용을 제공할 수 있습니다. 또한, 산업 혁명 이후의 사회 구조 변화에 대한 통찰을 얻는 데 유익합니다.'}]
#
# [추천 결과]
# ---
# 📚 꼬물꼬물 거꾸로 역사수업 | 역모자들
# ![꼬물꼬물 거꾸로 역사수업](https://shopping-phinf.pstatic.net/main_32473358654.20250425073303.jpg)
#
# ✏️ 추천 이유
# 이 책은 역사 교육을 위한 구체적인 방법론을 제시하여, 학생들에게 역사적 사건을 더 잘 이해시키고 토론할 수 있는 기회를 제공합니다. 사용자가 원하는 깊이 있는 역사적 분석을 교육적 맥락에서 효과적으로 활용할 수 있는 자료입니다.
#
# 📍 대출 가능 여부
# - 강남구립개포하늘꿈도서관: (미소장)
# - 강남구립논현도서관: (미소장)
# - 강남구립논현문화마루도서관: (미소장)
# ---
#
# 📚 현대사회의 구조와 변동 - 신서 897 | 박길성
# ✏️ 추천 이유
# 역사적 사건들이 현대 사회에 미친 영향을 분석하는 데 있어 중요한 통찰을 제공합니다. 이는 사용자가 제2차 세계대전과 같은 큰 사건을 학생들에게 설명할 때 유용한 배경 지식을 제공할 것입니다.
#
# 📍 대출 가능 여부
# - 강남구립개포하늘꿈도서관: (미소장)
# - 강남구립논현도서관: (미소장)
# - 강남구립논현문화마루도서관: (미소장)
# ---
#
# 📚 한국사회복지정책론 | 신섭중
# ![한국사회복지정책론](https://shopping-phinf.pstatic.net/main_32469304776.20250510073525.jpg)
#
# ✏️ 추천 이유
# 한국 사회의 역사적 맥락과 사회적 이슈를 이해하는 데 도움을 줄 수 있는 자료로, 사용자가 학생들과 논의할 때 풍부한 내용을 제공할 수 있습니다. 또한, 산업 혁명 이후의 사회 구조 변화에 대한 통찰을 얻는 데 유익합니다.
#
# 📍 대출 가능 여부
# - 강남구립개포하늘꿈도서관: (미소장)
# - 강남구립논현도서관: (미소장)
# - 강남구립논현문화마루도서관: (미소장)
# ---

# %% [markdown]
# ## 7. 다중 페르소나 배치 평가

# %%
async def run_batch_evaluation(persona_dict: dict, base_thread_id: str = "batch"):
    global user_to_csr, csr_to_user
    batch_results = []

    for i, (name, persona) in enumerate(persona_dict.items()):
        print(f"\n{'='*50}")
        print(f"[{i+1}/{len(persona_dict)}] 페르소나: {name}")
        print(f"{'='*50}")

        user_to_csr = queue.Queue()
        csr_to_user = queue.Queue()

        session_results = []
        thread_id = f"{base_thread_id}_{i}"

        await run_session(persona, session_results, thread_id)

        if session_results:
            result = session_results[0]
            result["persona_name"] = name
            batch_results.append(result)
            print(f"  완료: 추천 {len(result.get('recommendations', []))}건")

    print(f"\n배치 평가 완료: {len(batch_results)}/{len(persona_dict)} 성공")
    return batch_results

# 실행 (주석 해제 시 전체 페르소나 평가)
# all_results = await run_batch_evaluation(PERSONA_TEMPLATES)
